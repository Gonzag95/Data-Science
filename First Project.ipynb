# %% [markdown]
# Análisis Exploratorio de Datos

# %%
# COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO
import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
# COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO
data = pd.read_csv('C:/Users/Arido 1/Desktop/DS Acamica/Bitacoras/Sprint 1/DS_Proyecto_01_Datos_Properati.csv')
dataf=pd.DataFrame(data)
print ("El dataset tiene ", dataf.index.shape[0], " filas");
print ("El dataset tiene ", dataf.columns.shape[0], " columnas");
print ("Por lo tanto el dataset es de  [",data.index.shape[0],"x",data.columns.shape[0],"]");
print("Cinco primeras instancias: ");
dataf.head()
# Out:
# El dataset tiene  146660  filas
# El dataset tiene  19  columnas
# Por lo tanto el dataset es de  [ 146660 x 19 ]
# Cinco primeras instancias:
#    start_date    end_date  created_on        lat        lon         l1  \
# 0  2019-10-17  2019-12-23  2019-10-17 -34.605880 -58.384949  Argentina
# 1  2019-10-17  2019-11-21  2019-10-17 -34.624056 -58.412110  Argentina
# 2  2019-10-17  2019-11-01  2019-10-17 -34.593569 -58.427474  Argentina
# 3  2019-10-17  2019-12-23  2019-10-17 -34.581294 -58.436754  Argentina
# 4  2019-10-17  2020-03-11  2019-10-17 -34.914194 -57.938219  Argentina
#
#                        l2             l3  rooms  bedrooms  bathrooms  \
# 0         Capital Federal  San Cristobal    7.0       7.0        2.0
# 1         Capital Federal          Boedo    2.0       1.0        2.0
# 2         Capital Federal        Palermo    2.0       1.0        1.0
# 3         Capital Federal        Palermo    2.0       1.0        1.0
# ...

# %% [markdown]
# Imprimo en pantalla los nombres de las columnas y cuántos valores faltantes hay por columna.

# %%
# COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO
print ("Datos faltantes: ")
print(data.isna().sum()); ## ME DEVUELVE LA CANTIDAD DE DATOS FALTANTES EN CADAA COLUMNA
# Out:
# Datos faltantes:
# start_date             0
# end_date               0
# created_on             0
# lat                 9925
# lon                 9959
# l1                     0
# l2                     0
# l3                     0
# rooms                  0
# bedrooms               0
# bathrooms           5957
# surface_total      20527
# surface_covered    21614
# price                  0
# currency               0
# title                  0
# description            0
# property_type          0
# operation_type         0
# dtype: int64

# %% [markdown]
# ¿Cuántos tipos de propiedad hay publicados según este dataset?¿Cuántos instancias por cada tipo de propiedad hay en el dataset?

# %%
# COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO
# CUANTOS TIPOS DE PROPIEDAD HAY, DEPENDE EN BASE A QUE CLASIFICACION NOS BASEMOS. 

print("EXISTEN LOS SIGUIENTES TIPOS DE PROPIEDADES PUBLICADOS EN EL DATASET: \n")
print(pd.unique(dataf.property_type),"\n")
print("POR CADA TIPO DE PROPIEDAD, EXISTEN LAS SIGUIENTES INSTANCIAS: \n")
print(pd.Series(dataf.property_type.value_counts())) # SERIES ME DEVUELVE UN ARREGLO DE UN INDEX Y AL COSTADO INDICANDO
# LOS VALORES CORRESPONDIENTES A LAS COLUMNAS, Y VA CONTANDO CUANTAS VECES SE REPITE 
# CON LA FUNCION VALUE_COUNTS PUEDO REALIZAR LA SUMA Y ASI OBTENGO EL ARREGLO DE ABAJO
# Out:
# EXISTEN LOS SIGUIENTES TIPOS DE PROPIEDADES PUBLICADOS EN EL DATASET:
#
# ['Departamento' 'PH' 'Casa' 'Lote' 'Casa de campo' 'Oficina' 'Otro'
#  'Local comercial' 'Cochera' 'Depósito']
#
# POR CADA TIPO DE PROPIEDAD, EXISTEN LAS SIGUIENTES INSTANCIAS:
#
# Departamento       107326
# Casa                21521
# PH                  14298
# Lote                 1312
# Oficina               658
# Otro                  374
# Local comercial       325
# Casa de campo         322
# Depósito              265
# Cochera               259
# Name: property_type, dtype: int64

# %% [markdown]
# ¿De qué regiones son las publicaciones?

# %%
# COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO
import matplotlib.pyplot as plt
print("LOS BARRIOS QUE POSEE EL DEATASET SON LAS SIGUIENTES: \n")
print(pd.Series(dataf.l3.value_counts()))
print("LAS ZONAS QUE POSEE EL DEATASET SON LAS SIGUIENTES: \n")
print(pd.Series(dataf.l2.value_counts()))



x_l3= dataf[['l3']]
x_l2=dataf[['l2']]
fig= plt.figure(figsize=(30,25))

plt.subplot(2,1,1)
sns.countplot(x='l3', data=dataf, order = dataf['l3'].value_counts().index)
plt.title('Histograma Barrios')
plt.xticks(rotation=90)  
plt.subplot(2,1,2)
sns.countplot(x='l2', data=dataf, order = dataf['l2'].value_counts().index)
plt.title('Histograma Zonas')

fig.subplots_adjust(hspace=0.3)
  
plt.tick_params(axis='both', which='both', labelsize=7)
#ax2.tick_params(axis='both', which='both', labelsize=7)

#plt.tight_layout()
#ax1.set_xlabel(str(x1[1]))
# Out:
# LOS BARRIOS QUE POSEE EL DEATASET SON LAS SIGUIENTES:
#
# Palermo            13073
# Tigre               8718
# Almagro             7527
# Belgrano            6935
# Caballito           6650
#                    ...
# Cañuelas             108
# Villa Soldati         69
# Villa Riachuelo       42
# Marcos Paz            35
# Catalinas              5
# Name: l3, Length: 89, dtype: int64
# LAS ZONAS QUE POSEE EL DEATASET SON LAS SIGUIENTES:
#
# Capital Federal             92539
# Bs.As. G.B.A. Zona Norte    24282
# Bs.As. G.B.A. Zona Sur      17173
# Bs.As. G.B.A. Zona Oeste    12666
# Name: l2, dtype: int64

# %% [markdown]
# Selecciono las tres clases más abundantes de tipos de propiedad y la región con más propiedades publicadas

# %%
# COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO

# Recuerdo las clases, sitios y sus cantidades :
print ("Tipos de propiedad:  \n" )
print(pd.Series(dataf.property_type.value_counts()),"\n")
print ("Regiones publicadas:  \n" )
print(pd.Series(dataf.l2.value_counts()),"\n")

#HAGO EL RECORTE: 
datafnew = dataf[dataf['property_type'].isin(['Departamento','PH','Casa']) & (dataf['l2'] == 'Capital Federal')]
print("Mi nuevo data set tiene un tamaño de : ",datafnew.shape)

datafnew.head()
# Out:
# Tipos de propiedad:
#
# Departamento       107326
# Casa                21521
# PH                  14298
# Lote                 1312
# Oficina               658
# Otro                  374
# Local comercial       325
# Casa de campo         322
# Depósito              265
# Cochera               259
# Name: property_type, dtype: int64
#
# Regiones publicadas:
#
# Capital Federal             92539
# Bs.As. G.B.A. Zona Norte    24282
# Bs.As. G.B.A. Zona Sur      17173
# Bs.As. G.B.A. Zona Oeste    12666
# Name: l2, dtype: int64
#
# Mi nuevo data set tiene un tamaño de :  (91485, 19)
#    start_date    end_date  created_on        lat        lon         l1  \
# 0  2019-10-17  2019-12-23  2019-10-17 -34.605880 -58.384949  Argentina
# 1  2019-10-17  2019-11-21  2019-10-17 -34.624056 -58.412110  Argentina
# 2  2019-10-17  2019-11-01  2019-10-17 -34.593569 -58.427474  Argentina
# 3  2019-10-17  2019-12-23  2019-10-17 -34.581294 -58.436754  Argentina
# ...

# %% [markdown]
# FILTRADO DEL DATASET

# %%
#COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO
import matplotlib.pyplot as plt
import seaborn as sns

print("Estudio de las variales individualmente:\n")
x1= datafnew[['rooms']]
x2= datafnew[['bedrooms']]
x3= datafnew[['bathrooms']]
x4= datafnew[['surface_total']]
x5= datafnew[['surface_covered']]
x6= datafnew[['price']]
print(x1.describe())
print(x2.describe())
print(x3.describe())
print(x4.describe())
print(x5.describe())
print(x6.describe())

#Grafico histograma surface total
#plt.hist(x4,bins=12000, histtype='barstacked',color='red',rwidth=0.9)
#plt.xlim(0,700)
#plt.title("SUPERFICIE ANTES DEL RECORTE")
#plt.show()

#Grafico hist Precio
# Out:
# Estudio de las variales individualmente:
#
#               rooms
# count  91485.000000
# mean       2.964278
# std        1.314704
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max       26.000000
#            bedrooms
# count  91485.000000
# mean       1.960278
# std        1.072946
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       15.000000
#           bathrooms
# count  89314.000000
# mean       1.560147
# std        0.860309
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       14.000000
#        surface_total
# count   82568.000000
# mean      112.626369
# std       980.713664
# min        10.000000
# 25%        49.000000
# 50%        71.000000
# 75%       111.000000
# max    126062.000000
#        surface_covered
# count     82250.000000
# mean         94.966310
# std         778.515243
# min           1.000000
# 25%          44.000000
# ...

# %% [markdown]
# Recorte surface Total

# %%
import warnings
warnings.filterwarnings('ignore')

#Grafico surface old
#plt.xlim(0,500)


m=x4.mean()
std= (x4.std(ddof = 1))*3 # HAGO 3*EL DESVIO
surfmax= m+std # SE LO SUMO A LA MEDIA , AQUI ES DONDE VOY A CORTAR SURFACE-TOTAL
x4new= x4[(x4<surfmax)] # REALIZO UN CORTE EN LA MEDIA + 3*DESVIO ESTANDAR
x4new.dropna()


# GUARDO LAS VARIABLES EN MI DATASET
datafnew['surface_total'] = x4new['surface_total']

print("Superficie Total antes de recortar", x4.describe())
print("Superficie Total Recortada", x4new.describe())
print("-------------------------------")
print("Shape Total antes de recortar", x4.shape)
print("Shape Total Recortada", x4new.shape)
print("Datos nulos de sup antes de recortar",x4.isna().sum())
print("Datos nulos de sup despues de recortar",x4new.isna().sum())
#Grafico nuevo
#print("Superficie Total Recortada: ",X4new.describe())
fig, (ax0,ax1) = plt.subplots(2,1,figsize=(20,20))
sns.boxplot(ax=ax0,data=x4new, orient="h").set(title='Superficie Total luego del recorte', xlim=(0, 2500))
sns.boxplot(ax=ax1,data=x4, orient="h").set(title='Superficie Total antes del recorte') # HICE UN BOXPLOT PARA BORRAR LOS DATOS ATIPICOS
#sns.distplot(x4, bins = 20, kde=1, rug=True) #HISTOGRAMA DE SURFACE TOTAL: FUNCION EXPONENCIAL DECRECIENTE
# Out:
# Superficie Total antes de recortar        surface_total
# count   82568.000000
# mean      112.626369
# std       980.713664
# min        10.000000
# 25%        49.000000
# 50%        71.000000
# 75%       111.000000
# max    126062.000000
# Superficie Total Recortada        surface_total
# count   82451.000000
# mean       95.905301
# std        84.095904
# min        10.000000
# 25%        49.000000
# 50%        71.000000
# 75%       110.000000
# max      3032.000000
# -------------------------------
# Shape Total antes de recortar (91485, 1)
# Shape Total Recortada (91485, 1)
# Datos nulos de sup antes de recortar surface_total    8917
# dtype: int64
# Datos nulos de sup despues de recortar surface_total    9034
# dtype: int64
# [Text(0.5, 1.0, 'Superficie Total antes del recorte')]

# %% [markdown]
# RECORTO SURFACE COVERED

# %%
x5old = dataf['surface_covered']
datafsc = datafnew[(datafnew['surface_covered'] <= x4new['surface_total'])] # FILTRO POR SURFACECOVERED<SURFACETOTAL
x5new = datafsc['surface_covered']
x5new.dropna()
print("Surface Covered New: ", x5new.describe(),"\n")
print("Veo la diferencia con Surface Total: ", x4new.describe())
fig= plt.figure(figsize=(20,20))
plt.subplot(2,1,1)
sns.boxplot(data=x5old, orient="h").set(title='Superficie cubierta antes del recorte')  #HISTOGRAMA DE SURFACE TOTAL: FUNCION EXPONENCIAL DECRECIENTE
plt.subplot(2,1,2)
sns.boxplot(data=x5new, orient="h").set(title='Superficie cubierta luego del recorte')  #HISTOGRAMA DE SURFACE TOTAL: FUNCION EXPONENCIAL DECRECIENTE
# Out:
# Surface Covered New:  count    81175.000000
# mean        82.426769
# std         66.293746
# min          1.000000
# 25%         44.000000
# 50%         63.000000
# 75%         96.000000
# max       2773.000000
# Name: surface_covered, dtype: float64
#
# Veo la diferencia con Surface Total:         surface_total
# count   82451.000000
# mean       95.905301
# std        84.095904
# min        10.000000
# 25%        49.000000
# 50%        71.000000
# 75%       110.000000
# max      3032.000000
# [Text(0.5, 1.0, 'Superficie cubierta luego del recorte')]

# %%
#VEO QUE LOS DATOS DE SURFACE COVERED NEW, ESTAN POR DEBAJO DE SURFACE TOTAL NEW

# %% [markdown]
# RECORTO PRECIO

# %%
mprice= x6.mean()
stdprice = (x6.std(ddof = 1))*3
x6new = x6[x6<(mprice+stdprice)] # LIMITO A PRICE, EN SU MEDIA + 3 VECES SU DESVIO ESTANDAR
x6new.dropna()
fig, (ax0,ax1) = plt.subplots(2,1,figsize=(20,20))
sns.boxplot(ax=ax1,data=x6new, orient="h").set(title='Precio luego del recorte')# HICE UN BOXPLOT PARA BORRAR LOS DATOS ATIPICOS
sns.boxplot(ax=ax0,data=x6, orient="h").set(title='Precio antes del recorte')
print("Precio Recortado", x6new.describe(), "\n")
print ("Precio antes del recorte", x6.describe())
# Out:
# Precio Recortado               price
# count  8.980900e+04
# mean   2.280750e+05
# std    1.726302e+05
# min    6.000000e+03
# 25%    1.200000e+05
# 50%    1.740000e+05
# 75%    2.690000e+05
# max    1.225000e+06
#
# Precio antes del recorte               price
# count  9.148500e+04
# mean   2.595003e+05
# std    3.222654e+05
# min    6.000000e+03
# 25%    1.200000e+05
# 50%    1.750000e+05
# 75%    2.790000e+05
# max    3.243423e+07

# %%
#ANALIZO EL RESTO DE MIS ATRIBUTOS : 
#x1= datafnew[['rooms']]
#x2= datafnew[['bedrooms']] #Recuerdo mis x 
#x3= datafnew[['bathrooms']]
plt.figure(figsize=(20,10))
plt.subplot(3,1,1)
sns.boxplot(data=x1, orient="h")
plt.subplot(3,1,2)
sns.boxplot(data=x2, orient="h")
plt.subplot(3,1,3)
sns.boxplot(data=x3, orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# OBSERVO QUE LOS 3 ATRIBUTOS TIENEN CERCA DE 10 VALORES ATIPICOS, POR LO TANTO VOY A REALIZAR EL RECORTE DE LAS 3 VARIABLES :
# A UN VALOR DE 3 * SU DESVIACION ESTANDAR.

# %%
#RECORTO ROOMS
mr= x1.mean()
stdr = (x1.std(ddof = 1))*3
x1new = x1[x1<(mr+stdr)] # LIMITO A PRICE, EN SU MEDIA + 3 VECES SU DESVIO ESTANDAR
x1new.dropna()
fig= plt.figure(figsize=(20,20))
plt.subplot(2,1,1)
sns.boxplot(data=x1, orient="h").set(title='Rooms antes del recorte')
plt.subplot(2,1,2)
sns.boxplot(data=x1new, orient="h").set(title='Rooms despues del recorte')
# Out:
# [Text(0.5, 1.0, 'Rooms despues del recorte')]

# %%
#RECORTO BEDROOMS
mb= x2.mean()
stdb = (x2.std(ddof = 1))*3
x2new = x2[x2<(mb+stdb)] # LIMITO A PRICE, EN SU MEDIA + 3 VECES SU DESVIO ESTANDAR
x2new.dropna()
fig= plt.figure(figsize=(20,20))
plt.subplot(2,1,1)
sns.boxplot(data=x2, orient="h").set(title='Bedooms antes del recorte')
plt.subplot(2,1,2)
sns.boxplot(data=x2new, orient="h").set(title='Bedooms despues del recorte')
# Out:
# [Text(0.5, 1.0, 'Bedooms despues del recorte')]

# %%
#RECORTO BATHROOMS
mbeth= x3.mean()
stdbeth = (x3.std(ddof = 1))*3
x3new = x3[x3<(mbeth+stdbeth)] # LIMITO A PRICE, EN SU MEDIA + 3 VECES SU DESVIO ESTANDAR
x3new.dropna()
fig= plt.figure(figsize=(20,20))
plt.subplot(2,1,1)
sns.boxplot(data=x3, orient="h").set(title='Bathrooms antes del recorte')
plt.subplot(2,1,2)
sns.boxplot(data=x3new, orient="h").set(title='Bathrooms despues del recorte')
# Out:
# [Text(0.5, 1.0, 'Bathrooms despues del recorte')]

# %%
import warnings
warnings.filterwarnings('ignore')
# GUARDO LAS VARIABLES EN MI DATASET
datafnew['surface_total'] = x4new['surface_total']
datafnew['surface_covered'] = x5new
datafnew['price'] = x6new['price']
datafnew['rooms'] = x1new['rooms']
datafnew['bedrooms'] = x2new['bedrooms']
datafnew['bathrooms'] = x3new['bathrooms']
datafnew['Surface Free'] = datafnew['surface_total'] - datafnew['surface_covered']

# %%
#datafnew['surface_covered'].describe()

# %%
datafnew.head()
# Out:
#    start_date    end_date  created_on        lat        lon         l1  \
# 0  2019-10-17  2019-12-23  2019-10-17 -34.605880 -58.384949  Argentina
# 1  2019-10-17  2019-11-21  2019-10-17 -34.624056 -58.412110  Argentina
# 2  2019-10-17  2019-11-01  2019-10-17 -34.593569 -58.427474  Argentina
# 3  2019-10-17  2019-12-23  2019-10-17 -34.581294 -58.436754  Argentina
# 5  2019-10-17  2019-11-01  2019-10-17 -34.593779 -58.441239  Argentina
#
#                 l2             l3  rooms  bedrooms  bathrooms  surface_total  \
# 0  Capital Federal  San Cristobal    NaN       NaN        2.0          140.0
# 1  Capital Federal          Boedo    2.0       1.0        2.0           70.0
# 2  Capital Federal        Palermo    2.0       1.0        1.0           45.0
# 3  Capital Federal        Palermo    2.0       1.0        1.0           85.0
# 5  Capital Federal   Villa Crespo    2.0       1.0        1.0           56.0
#
#    surface_covered     price currency  \
# ...

# %% [markdown]
# 7. **Correlaciones:** Estudia la correlación entre las variables `rooms`, `bedrooms`, `bathrooms`, `surface_total`, `surface_covered`, `price`. ¿Cuáles son las mejores variables para predecir el precio?¿Qué diferencias encuentras según cada tipo de propiedad?

# %%
datafnew=datafnew.dropna() #SACO LOS VALORES NULOS
datafnew.corr()
# Out:
#                       lat       lon     rooms  bedrooms  bathrooms  \
# lat              1.000000 -0.100530 -0.025021 -0.035247   0.095735
# lon             -0.100530  1.000000  0.044331  0.035791   0.060838
# rooms           -0.025021  0.044331  1.000000  0.936464   0.583046
# bedrooms        -0.035247  0.035791  0.936464  1.000000   0.588325
# bathrooms        0.095735  0.060838  0.583046  0.588325   1.000000
# surface_total   -0.020246 -0.001870  0.631886  0.618240   0.531759
# surface_covered  0.002989  0.059800  0.675276  0.659646   0.579461
# price            0.235123  0.160209  0.565116  0.536840   0.659568
# Surface Free    -0.049810 -0.106588  0.237811  0.234469   0.180960
#
#                  surface_total  surface_covered     price  Surface Free
# lat                  -0.020246         0.002989  0.235123     -0.049810
# lon                  -0.001870         0.059800  0.160209     -0.106588
# rooms                 0.631886         0.675276  0.565116      0.237811
# ...

# %% [markdown]
# SEGUN LAS CORRELACIONES CON EL PRECIO : SURFACE_COVERED ES LA QUE MAS CORRELACION PARECE TENER,
# SEGUIDO POR SURFACE_TOTAL COMO ERA DE ESPERAR, AL IGUAL QUE BATHROOMS TIENE UNA ALTA CORRELACION
# LE SIGUE ROOMS AND BEDROOMS

# %%
datafstudy = datafnew.filter(['rooms','bedrooms','bathrooms','surface_total','surface_covered','price','property_type'], axis=1)
datafstudy.head()
# ME CREO UN DATAF DE ESTUDIO, CON LAS VARIABLES QUE CREO QUE SON LAS MAS IMPORTANTES PARA ESTIMAR EL PRECIO, PARA LUEGO
#PODER REALIZAR UN PAIRPLOT DE FORMA MAS SENCILLA Y VER LOS GRAFICOS.
# Out:
#    rooms  bedrooms  bathrooms  surface_total  surface_covered     price  \
# 1    2.0       1.0        2.0           70.0             58.0  159000.0
# 2    2.0       1.0        1.0           45.0             45.0  125000.0
# 3    2.0       1.0        1.0           85.0             50.0  295000.0
# 5    2.0       1.0        1.0           56.0             56.0  150000.0
# 6    2.0       1.0        1.0           70.0             70.0  159500.0
#
#   property_type
# 1            PH
# 2            PH
# 3            PH
# 5            PH
# 6            PH

# %%
# COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO
#import warnings
#warnings.filterwarnings('ignore')
#sns.set()
#sns.pairplot(datafstudy, hue='price')

# %%
#VARIABLES QUE MEJOR ME PUEDEN SERVIR PARA ESTIMAR PRECIO DEBIDO A LA DISTRIBUCION DE LOS PUNTOS EN LOS GRAFICOS: 
#    - BATHROOMS VS BEDROOMS
#    - ROOMS VS BATHROOMS
#    - ROOMS VS BEDR00MS
#    - ROOMS VS SURFACE_TOTAL
#    - ROOMS VS SURFACE_COVERED

# %% [markdown]
# ### 2.1 Desafío
#
# En el dataset provisto hay mucha información, más allá del problema planteado. Propone una pregunta que pueda ser respondida por el dataset e intenta responderla.¿Cuáles son los sesgos de la respuesta obtenida?(¿Cuán generalizable es la respuesta obtenida?)¿Necesitas información complementaria?¿Cómo la obtendrías?
#
# Por ejemplo: ¿Cuál es el barrio más caro de Buenos Aires? Probablemente puedas responder esta pregunta con este dataset. Pero podria ocurrir que la respuesta esté sesgada. ¿Cómo? Tal vez las propiedades más caras no se publican de forma online, sino que utilizan otro canal de venta.

# %% [markdown]
#     ¿ COMO VARIA EL PRECIO EN CUANTO A LA DISTANCIA AL OBELISCO ?
#     - PREGUNTA QUE SE PUEDE RESPONDER CON MI DATASET

# %%
import haversine as hs
from haversine import Unit
import numpy as np
coordinates = datafnew[['lat', 'lon']].to_numpy()
coordinateobelisc= np.array([-34.60376, -58.38162])
#coordinates = np.reshape(coordinates,(146660,2))
#print(coordinates)
distance=[]
i=0
for i in range (0,73567): 
        dx= hs.haversine(coordinates[i],coordinateobelisc)#unit=Unit.METERS) #CALCULO LA DISTANCIA INDIVIDUALMENTE EN KILOMETROS
        distance.append(dx) #LO AGREGO A MI VECTOR DISTANCIA
             
distance = np.array(distance)
distance= pd.DataFrame(distance)
datafnew['distance_obelisc'] = distance
#print(datafnew.distance_obelisc.index.shape)
#datafnew.price.head(100)
#datafnew = datafnew.sort_values(by='price')
plt.figure(figsize=(20,20))
sns.scatterplot(x=datafnew['distance_obelisc'], y=datafnew['price'],hue=datafnew['property_type'], data=datafnew)
plt.title('PRECIO EN FUNCION DE LA DISTANCIA AL OBELISCO')
#datafnew.corr()
# Out:
# Text(0.5, 1.0, 'PRECIO EN FUNCION DE LA DISTANCIA AL OBELISCO')

# %% [markdown]
# COMO PODEMOS OBSERVAR EN EL GRAFICO, NO EXISTE ALGUN TIPO DE RELACION LINEAL ENTRE PRECIO, Y DISTANCIA AL OBELISCO
# POR LO TANTO PODEMOS DECIR, QUE CON NUESTRA MUESTRA DE DATOS, NO PODEMOS AFIRMAR LA HIPOTESIS DE QUE
# "A MEDIDA QUE AUMENTA LA DISTANCIA AL OBELISCO, DISMINUYE EL PRECIO ".
# QUIZAS CON OTRA MUESTRA DIFERENTE O CON MAYOR CANTIDAD DE DATOS LOGRAGRIAMOS AFIRMAR DICHA HIPOTESIS.
#
#
# ESTO TAMBIEN LO VAMOS A REAFIRMAR A CONTINUACION OBSERVANDO UNA CORRELACION MUY BAJA ENTRE
# DISTANCE_OBELISC Y PRICE :

# %%
datafnew.corr()
# Out:
#                        lat       lon     rooms  bedrooms  bathrooms  \
# lat               1.000000 -0.100530 -0.025021 -0.035247   0.095735
# lon              -0.100530  1.000000  0.044331  0.035791   0.060838
# rooms            -0.025021  0.044331  1.000000  0.936464   0.583046
# bedrooms         -0.035247  0.035791  0.936464  1.000000   0.588325
# bathrooms         0.095735  0.060838  0.583046  0.588325   1.000000
# surface_total    -0.020246 -0.001870  0.631886  0.618240   0.531759
# surface_covered   0.002989  0.059800  0.675276  0.659646   0.579461
# price             0.235123  0.160209  0.565116  0.536840   0.659568
# Surface Free     -0.049810 -0.106588  0.237811  0.234469   0.180960
# distance_obelisc  0.007041 -0.007246 -0.008681 -0.005823   0.004793
#
#                   surface_total  surface_covered     price  Surface Free  \
# lat                   -0.020246         0.002989  0.235123     -0.049810
# ...

# %% [markdown]
# ### 3. Machine Learning
#
# En esta sección, debes entrenar dos modelos de Machine Learning - uno de vecinos más cercanos y otro de árboles de decisión -  para predecir el precio de las propiedades tipo `Departamento`, `PH` y `Casa`  en la Ciudad Autónoma de Buenos Aires (`Capital Federal`). Para ello, no debes olvidarte de:
#
# * Elegir una métrica apropiada para evaluar los resultados de los modelos.
# * Seleccionar las variables predictoras (`X`) y la variable a predecir (`y`).
# * Realizar un Train/Test split de los datos.
# * Generar un modelo *benchmark* y evaluarlo.
# * Entrenar un modelo de vecinos más cercanos y un modelo de árbol de decisión con hiperparámetros iniciales de su elección.
# * Evaluar los modelos obtenidos. Para ello, evalúa la métrica elegida en el conjunto de Test y en el conjunto de Train. También, realiza gráficos de valores reales vs. valores predichos.
# * Mejorar el desempeño de sus modelos optimizando el número de vecinos y la profundidad del árbol, respectivamente.
# * Entre los modelos entrenados, ¿cuál elegirías para utilizar?¿Por qué?
# * Ser **crítico/a** con la metodología utilizada. Por ejemplo, responde las siguientes preguntas: ¿Qué información no estás usando que podría ayudar al modelo?¿Qué información puede estar demás o repetida?
#
# Estos lineamientos corresponden al **mínimo entregable** de esta sección.
#
#
# **Importante:** para asegurarnos que trabajes con un dataset apropiados, debes volver a cargar los datos y realizar el siguiente filtrado:
#
# 1. Selecciona aquellas propiedades en Capital Federal y cuyo tipo de propiedad es Departamento, PH o Casa.
# 1. Selecciona aquellas propiedades cuya superficie total es menor a 1000 m2 y mayor a 15 m2.
# 1. Selecciona aquellas propiedades cuya precio es menor 4000000 dólares.
# 1. Selecciona las columnas `rooms`, `bedrooms`, `bathrooms`, `surface_total`, `surface_covered` y `price`.
# 1. Descarta aquellas instacias con valores faltantes.
#
# **Checkpoint:** deberías obtener un dataset con 81019 instacias y 6 columnas.

# %%
# COMPLETAR - AGREGAR TANTAS CELDAS COMO SEA NECESARIO
propiedades_ML= dataf[(dataf.l2=='Capital Federal')&(dataf.property_type.isin(['Departamento','Casa','PH'])&(dataf.surface_total>=15)&(dataf.surface_total<=1000)&(dataf.price<=4000000))].drop(columns=['start_date', 'end_date', 'created_on', 'lat', 'lon', 'l1','l2','property_type', 'l3', 'currency', 'title', 'description', 'operation_type']).dropna()
#propiedades_ML.head()
print("EL DATASET POSEE UN TAMAÑO DE ",propiedades_ML.shape)
print("MATRIZ DE CORRELACIONES: \n",propiedades_ML.corr())
# Out:
# EL DATASET POSEE UN TAMAÑO DE  (81019, 6)
# MATRIZ DE CORRELACIONES:
#                      rooms  bedrooms  bathrooms  surface_total  \
# rooms            1.000000  0.925604   0.601887       0.725799
# bedrooms         0.925604  1.000000   0.605002       0.695523
# bathrooms        0.601887  0.605002   1.000000       0.651924
# surface_total    0.725799  0.695523   0.651924       1.000000
# surface_covered  0.304407  0.291140   0.275936       0.375749
# price            0.479972  0.442418   0.638737       0.686459
#
#                  surface_covered     price
# rooms                   0.304407  0.479972
# bedrooms                0.291140  0.442418
# bathrooms               0.275936  0.638737
# surface_total           0.375749  0.686459
# surface_covered         1.000000  0.298212
# price                   0.298212  1.000000

# %%
#MAYOR CORRELACION CON PRECIO :  BATHROOMS Y SURFACE_TOTAL
x1= propiedades_ML[['surface_total']]
x2= propiedades_ML[['bathrooms']]
y= propiedades_ML[['price']]
# RETIRO LOS VALORES NULOS
x1=x1.dropna()
x2= x2.dropna()
y=y.dropna()
#y.describe()
#print(x1.describe())
#print(x2.describe())
#print(y.describe())
#print(x1.shape)
#print(x2.shape)

# %%
#import matplotlib as plt 
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt



def plot_3d_scatter(x1, x2, y, ax=None, fig = None):
    if (fig is None) and (ax is None):
        fig = plt.figure(figsize = (8,6))
        ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x1, x2, y, alpha=0.2)

    ax.set_xlabel('Superficie Total')
    ax.set_ylabel('Baños')
    ax.set_zlabel('Precio')

# %%
fig = plt.figure(figsize = (12,4))
plot_3d_scatter(x1, x2, y, ax=None, fig = None)

# %%
X = np.vstack((x1.T,x2.T)).T
print("---------Testing shape--------------")
print(X.shape, y.shape)
# Out:
# ---------Testing shape--------------
# (81019, 2) (81019, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (56713, 2) (56713, 1) (24306, 2) (24306, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
linear_model = LinearRegression()
tree_regressor = DecisionTreeRegressor(max_depth=3, random_state=42)
knn_regressor = KNeighborsRegressor(n_neighbors=2)

# %%
linear_model.fit(X_train, y_train)
tree_regressor.fit(X_train, y_train)
knn_regressor.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
print(linear_model.coef_, linear_model.intercept_)
# Out:
# [[  1792.45489814 117299.06367811]] [-89674.22347676]

# %%
from matplotlib import cm

def plot_3d_regressor(x1_min, x1_max, x2_min,x2_max, N, regressor, ax=None, fig = None):
    x1 = np.linspace(x1_min,x1_max,N) 
    x2 = np.linspace(x2_min,x2_max,N)
    X1, X2 = np.meshgrid(x1,x2)
    
    y = regressor.predict(np.array([X1.ravel(), X2.ravel()]).T)
    Y = y.reshape(X1.shape)
    
    if (fig is None) and (ax is None):
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
    
    surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False, alpha = 0.5)

# %%
fig = plt.figure(figsize = (12,4))
ax = fig.add_subplot(131, projection='3d')
plt.title('Regresión Lineal')
plot_3d_regressor(15, 1000, 1, 14, 100, linear_model, ax, fig)
plot_3d_scatter(x1, x2, y, ax, fig)


ax = fig.add_subplot(132, projection='3d')
plt.title('Árbol de Decisión')
plot_3d_regressor(15, 1000, 1, 14, 100, tree_regressor, ax, fig)
plot_3d_scatter(x1, x2, y, ax, fig)

ax = fig.add_subplot(133, projection='3d')
plt.title('Vecinos más cercanos')
plot_3d_regressor(15, 1000, 1, 14, 100, knn_regressor, ax, fig)
plot_3d_scatter(x1, x2, y, ax, fig)

plt.tight_layout()
plt.show()

# %%
from sklearn import tree

if tree_regressor.max_depth < 4:
    plt.figure(figsize = (20,10))
    tree.plot_tree(tree_regressor, filled = True)
    plt.show()

# %%
from sklearn.metrics import mean_squared_error
import seaborn as sns
modelos = ['Regresión lineal', 'Árbol de Decisión', 'Vecinos más cercanos']
j=0
plt.figure(figsize = (10,10))
for i, model in enumerate([linear_model, tree_regressor, knn_regressor]):
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    if modelos[i] == 'Árbol de Decisión':
        y_test_pred= pd.DataFrame(y_test_pred, columns=['price'])
        y_train_pred= pd.DataFrame(y_train_pred, columns=['price'])
        
    #print (y_train.shape)
    #print (y_train_pred.shape)
    print(f'Modelo: {modelos[i]}')
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    print(f'Raíz del error cuadrático medio en Train: {rmse_train}')
    print(f'Raíz del error cuadrático medio en Test: {rmse_test}')
    
    j+=1
    plt.subplot(3,2,j)
    plt.title(modelos[i])
    sns.distplot(y_train - y_train_pred, bins = 20, label = 'train')
    sns.distplot(y_test - y_test_pred, bins = 20, label = 'test')
    plt.xlabel('errores')
    plt.legend()
    j+=1
    plt.subplot(3,2,j)
    plt.scatter(y_test,y_test_pred, s =2)    
    lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes]
    ]
    
    plt.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    plt.xlabel('y (test)')
    plt.ylabel('y_pred (test)')
    
plt.tight_layout()
plt.show()
# Out:
# Modelo: Regresión lineal
# Raíz del error cuadrático medio en Train: 203015.35633339902
# Raíz del error cuadrático medio en Test: 205955.81413686316
# Modelo: Árbol de Decisión
# Raíz del error cuadrático medio en Train: 202993.54524281574
# Raíz del error cuadrático medio en Test: 204792.88471910908
# Modelo: Vecinos más cercanos
# Raíz del error cuadrático medio en Train: 172078.80650951128
# Raíz del error cuadrático medio en Test: 196850.92191850237

# %% [markdown]
# EL ERROR MAS PEQUEÑO EN BENCHMARK:  Raíz del error cuadrático medio en Test: 196850.92191850237 CORRESPONDIENTE AL MODELO KNN CON UN K =2

# %% [markdown]
# A CONTINUACION BUSCAMOS EL MEJOR HIPERPARAMETRO (OPTIMIZACION), BASANDONOS EN LA VARIACION DE LA RAIZ CUADRADA DEL ERROR
# CUADRATICO MEDIO. ¿ PORQUE ELEGI ESTA METRICA ?
# ME BASE EN ESTA METRICA YA QUE COMO VIMOS ANTERIORMENTE, EL DATASET POSEE ATRIBUTOS LOS CUALES LA MAYORIA SE ENCUENTRAN EN
# DIFERENTES UNIDADES CON RESPECTO A NUESTRA ETIQUETA A PREDECIR: EL PRECIO. LO CUAL ESTO NO SERIA UN PROBLEMA A LA HORA DE
# TRABAJAR CON RMSE. FINALMENTE, ITERANDO EN LOS HIPERARAMETROS DE LOS DIFERENTES MODELOS DE PREDICCION, Y A SU VEZ MIDIENDO EL
# ERROR DEL MISMO, PUEDO ENCONTRAR EL HIPERPARAMETRO OPTIMO PARA MI MODELO QUE A SU VEZ GENERE EL ERROR MAS BAJO POSIBLE. DE ESTA FORMA LOGRO OPTIMIZAR MI HIPERPARAMETRO Y A SU VEZ EVALUAR EL MODELO.
#
# LUEGO SE CAMBIARAN LA CANTIDAD DE ATRIBUTOS PARA VERIFICAR QUE FUERON BIEN ELEGIDOS.

# %%
#REGRESION LINEAL
#modelos = ['Regresión lineal', 'Árbol de Decisión', 'Vecinos más cercanos']
#for i, model in enumerate([linear_model, tree_regressor, knn_regressor]):
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
y_train_pred = knn_regressor.predict(X_train)
y_test_pred = knn_regressor.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
print(f'Raíz del error cuadrático medio en Test con el modelo de REGRESION LINEAL: {rmse_test}')
print(f'Raíz del error cuadrático medio en Train con el modelo de REGRESION LINEAL: {rmse_train}')
# Out:
# Raíz del error cuadrático medio en Test con el modelo de REGRESION LINEAL: 196850.92191850237
# Raíz del error cuadrático medio en Train con el modelo de REGRESION LINEAL: 172078.80650951128

# %%
#ARBOL DE DECICION
treerror = []
ntree= []
trainerror=[]
for n in range(1,100,1):
    tree_regressor = DecisionTreeRegressor(max_depth=n, random_state=42)
    tree_regressor.fit(X_train, y_train)
    y_test_pred = tree_regressor.predict(X_test)
    y_train_pred = tree_regressor.predict(X_train)
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    treerror.append(rmse_test)
    trainerror.append(rmse_train)
    ntree.append(n)
    print(f'Raíz del error cuadrático medio en Train con TREE REGRESOR: {rmse_train} con un K de {n} \n')
    print(f'Raíz del error cuadrático medio en Test con TREE REGRESOR: {rmse_test}  con un K de {n} \n')
# Out:
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 241977.38590562774 con un K de 1
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 246824.56631912984  con un K de 1
#
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 215485.17059517483 con un K de 2
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 219189.80785344192  con un K de 2
#
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 202993.54524281574 con un K de 3
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 204792.88471910908  con un K de 3
#
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 192526.38173880798 con un K de 4
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 196464.14374008845  con un K de 4
#
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 188213.4030140634 con un K de 5
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 191674.50660043233  con un K de 5
#
# ...

# %%
#KNN REGRESOR
for n in range(1,1000,50):
    knn_regressor = KNeighborsRegressor(n_neighbors=n)
    knn_regressor.fit(X_train, y_train)
    y_train_pred = knn_regressor.predict(X_train)
    y_test_pred = knn_regressor.predict(X_test)
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    print(f'Raíz del error cuadrático medio en Test con KNN REGRESOR: {rmse_test}  Con un K de {n} \n')
    print(f'Raíz del error cuadrático medio en Train con KNN REGRESOR: {rmse_train} con un K de {n} \n')
# Out:
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 224468.82037948148  Con un K de 1
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 198581.15091851936 con un K de 1
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 193423.21992628186  Con un K de 51
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 183911.47040131566 con un K de 51
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 202731.8423924933  Con un K de 101
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 196201.2137704687 con un K de 101
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 207196.27770081916  Con un K de 151
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 201590.47355844104 con un K de 151
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 209421.76517410023  Con un K de 201
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 204150.83934573337 con un K de 201
#
# ...

# %% [markdown]
# VEO QUE EL ERROR CUADRATICO MEDIO MAS BAJO SE ENCUENTRA ENTRE 1 Y 100, POR LO TANTO REALIZO UN ANALISIS DENTRO DE ESE RANGO

# %%
error = []
ngraph=[]
trainerrork=[]
for n in range(1,100,1):
    knn_regressor = KNeighborsRegressor(n_neighbors=n)
    knn_regressor.fit(X_train, y_train)
    y_train_pred = knn_regressor.predict(X_train)
    y_test_pred = knn_regressor.predict(X_test)
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    error.append(rmse_test)
    trainerrork.append(rmse_train)
    ngraph.append(n)
    print(f'Raíz del error cuadrático medio en Test con KNN REGRESOR: {rmse_test}  Con un K de {n} \n')
    print(f'Raíz del error cuadrático medio en Train con KNN REGRESOR: {rmse_train}  Con un K de {n} \n')
# Out:
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 224468.82037948148  Con un K de 1
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 198581.15091851936  Con un K de 1
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 196850.92191850237  Con un K de 2
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 172078.80650951128  Con un K de 2
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 188033.34357745922  Con un K de 3
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 163314.0849891205  Con un K de 3
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 183584.23230560456  Con un K de 4
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 161188.45497441225  Con un K de 4
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 181732.7963361336  Con un K de 5
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 161891.72981294463  Con un K de 5
#
# ...

# %%
#GRAFICO EL ERROR PARA KNN
#error = np.array(error)
#n = np.array(n)
plt.figure(figsize=(10,10))
plt.plot(ngraph, error, label='Test')
plt.plot(ngraph,trainerrork,label='Train')
diferenceerror = np.array(error)-np.array(trainerrork)
plt.plot(ngraph,diferenceerror,label='Diference')
#plt.plot(ngraph,(trainerrork-error),label='Diferencia')
plt.legend()
plt.xlabel('VARIACION DE K')
plt.title('KNN ERROR')
plt.xticks([i for i in range(0,100,3)]) 
plt.show()
print("El minimo error para KNN en Test lo encontramos en ", np.amin(error))
#print("El minimo error para KNN en Train lo encontramos en ", np.amin(trainerrork))
# Out:
# El minimo error para KNN en Test lo encontramos en  181732.7963361336

# %% [markdown]
# PODEMOS OBSERVAR, OBSERVANDO LA DIFERENCIA ENTRE EL ERRO DE TRAIN Y DE TEST, QUE EL MEJOR HIPERPARAMETRO, SIN OBTENER
# UN OVERFITTING EN NUESTRO MODELO, SE ENCUENTRA EN UN K DE 12 APROXIMADAMENTE, YA QUE ES AQUI CUANDO EL FITTING SE COMIENZA
# A APLANAR, Y ESTE ENTONCES ES EL PUNTO DE MENOR ERROR EVITANDO EL OVERFITTING.
# CON K=12 TENEMOS UN ERROR DE --------->  RMSE = 183302.53358427997

# %%
#REALIZO EL MISMO ANALISIS PARA EL ARBOL DE DECICION
plt.figure(figsize=(10,10))
plt.title('TREE REGRESOR ERROR')
plt.plot(ntree, treerror,label='Test')
plt.plot(ntree,trainerror,label='Train')
diferenceerror = np.array(treerror)-np.array(trainerror)
plt.plot(ngraph,diferenceerror,label='Diference')
plt.legend()
plt.xlabel('VARIACION DE PROFUNDIDAD')
plt.xticks([i for i in range(0,100,3)]) 
plt.show()
print("El minimo error para TREE REGRESOR en Test lo encontramos en ", np.amin(treerror))
#print("El minimo error para TREE REGRESOR en Train lo encontramos en ", np.amin(trainerror))
# Out:
# El minimo error para TREE REGRESOR en Test lo encontramos en  173652.40181045054

# %% [markdown]
# EN ESTE CASO SE PUEDE OBSERVAR QUE EL MEJOR HIPERPARAMETRO ESTA EN MAX_DEPTH = 9 APROXIMADAMENTE, YA QUE LUEGO EL ERROR
# SIGUE CRECIENDO Y COMIENZA A HABER OVERFFITING.
# POR LO TANTO CON MAX_DEEPH=9  ----------> RMSE = 177954.20409256668
#
#
# POR LO TANTO ENTRE AMBOS MODELOS Y ESTA CANTIDAD DE ATRIBUTOS, ES MEJOR EL MODELO DE TREE REGRESSOR CON UN MAX_DEEPH=9
#
#
# AHORA VAMOS A LLEVAR A CABO UN ANALISIS CON 3 ATRIBUTOS Y VAMOS A CONSIDERAR NUEVAMENTE LA EVALUACION DEL MODELO
# TENIENDO EN CUENTA A LA VARIACION DEL RMSE VARIANDO LOS HIPERPARAMETROS:

# %%
x1= propiedades_ML[['surface_total']]
x2= propiedades_ML[['bathrooms']]
y= propiedades_ML[['price']]
x3= propiedades_ML[['rooms']]

# RETIRO LOS VALORES NULOS

# RETIRO LOS VALORES NULOS
x1=x1.dropna()
x2= x2.dropna()
x3= x3.dropna()
y=y.dropna()

# %%
X = np.vstack((x1.T,x2.T,x3.T)).T
print("---------Testing shape--------------")
print(X.shape, y.shape)
# Out:
# ---------Testing shape--------------
# (81019, 3) (81019, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (56713, 3) (56713, 1) (24306, 3) (24306, 1)

# %%
#TREE REGRESSOR
trainerror=[]
treerror = []
ntree= []
for n in range(1,100,1):
    tree_regressor = DecisionTreeRegressor(max_depth=n, random_state=42)
    tree_regressor.fit(X_train, y_train)
    y_test_pred = tree_regressor.predict(X_test)
    y_train_pred = tree_regressor.predict(X_train)
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    treerror.append(rmse_test)
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    trainerror.append(rmse_train)
    ntree.append(n)
    print(f'Raíz del error cuadrático medio en Train con TREE REGRESOR: {rmse_train} con un K de {n} \n')
    print(f'Raíz del error cuadrático medio en Test con TREE REGRESOR: {rmse_test}  Con un K de {n} \n')
# Out:
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 241977.38590562774 con un K de 1
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 246824.56631912984  Con un K de 1
#
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 215485.17059517483 con un K de 2
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 219189.80785344192  Con un K de 2
#
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 202993.54524281574 con un K de 3
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 204792.88471910908  Con un K de 3
#
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 192505.6616415509 con un K de 4
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 196448.18441258877  Con un K de 4
#
# Raíz del error cuadrático medio en Train con TREE REGRESOR: 182656.335498715 con un K de 5
#
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 186986.27096500547  Con un K de 5
#
# ...

# %%
#KNN REGRESOR
for n in range(1,1000,100):
    knn_regressor = KNeighborsRegressor(n_neighbors=n)
    knn_regressor.fit(X_train, y_train)
    y_train_pred = knn_regressor.predict(X_train)
    y_test_pred = knn_regressor.predict(X_test)
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    print(f'Raíz del error cuadrático medio en Test con KNN REGRESOR: {rmse_test}  Con un K de {n} \n')
# Out:
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 189837.69121770567  Con un K de 1
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 202245.52530184956  Con un K de 101
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 209134.19548501255  Con un K de 201
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 211791.04547436384  Con un K de 301
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 212925.25523854836  Con un K de 401
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 213413.11265475128  Con un K de 501
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 213997.5867061043  Con un K de 601
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 214861.14915668636  Con un K de 701
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 215188.8155426235  Con un K de 801
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 215351.33093646198  Con un K de 901

# %% [markdown]
# AL IGUAL QUE ANTES, VEMOS QUE EN KNN EL ERROR MAS BAJO SE ENCUENTRA ENTRE UN K DE 1 Y 100.

# %%
error = []
ngraph=[]
trainerrork=[]

for n in range(1,100,1):
    knn_regressor = KNeighborsRegressor(n_neighbors=n)
    knn_regressor.fit(X_train, y_train)
    y_train_pred = knn_regressor.predict(X_train)
    y_test_pred = knn_regressor.predict(X_test)
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    error.append(rmse_test)
    ngraph.append(n)
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    trainerrork.append(rmse_train)
    print(f'Raíz del error cuadrático medio en Test con KNN REGRESOR: {rmse_test}  Con un K de {n} \n')
    print(f'Raíz del error cuadrático medio en Train con KNN REGRESOR: {rmse_train}  Con un K de {n} \n')
# Out:
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 189837.69121770567  Con un K de 1
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 146051.79635470503  Con un K de 1
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 175038.4341272347  Con un K de 2
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 136171.0158119831  Con un K de 2
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 172515.87080961574  Con un K de 3
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 138189.02291630057  Con un K de 3
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 169842.91229048057  Con un K de 4
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 140529.34216371732  Con un K de 4
#
# Raíz del error cuadrático medio en Test con KNN REGRESOR: 171271.21785149712  Con un K de 5
#
# Raíz del error cuadrático medio en Train con KNN REGRESOR: 143281.84069275638  Con un K de 5
#
# ...

# %% [markdown]
# AHORA GRAFICO LOS ERRORES Y ENCUENTRO EL ERROR MAS PEQUEÑO PARA AMBOS MODELOS

# %%
#GRAFICO EL ERROR PARA KNN
#error = np.array(error)
#n = np.array(n)
plt.figure(figsize=(10,10))
plt.plot(ngraph, error,label='Test')
plt.plot(ngraph,trainerrork,label='Train')
plt.title('KNN ERROR CON 3 ATRIBUTOS')
diferenceerror = np.array(error)-np.array(trainerrork)
plt.plot(ngraph,diferenceerror,label='Diference')
plt.legend()
plt.xlabel('VARIACION DE K')
plt.xticks([i for i in range(0,100,3)]) 
plt.show()
print("El minimo error para KNN Test lo encontramos en ", np.amin(error))
#print("El minimo error para KNN Train lo encontramos en ", np.amin(trainerrork))
# Out:
# El minimo error para KNN Test lo encontramos en  169842.91229048057

# %% [markdown]
# EN ESTE CASO PODEMOS OBSERVAR QUE EL MENOR ERROR SIN OBTENER OVERFITTING ESTA EN UN K = 11 APROXIMADAMENTE, YA QUE LUEGO DE ESTE VALOR, LA CURVA FITTING COMIENZA A APLANARSE Y COMIENZA A HABER OVERFITTING.
#
# POR LO TANTO UN K = 11 CONLLEVA UN ERROR DE ----------> 176287.42394264168

# %%
#REALIZO EL MISMO ANALISIS PARA EL ARBOL DE DECICION
fig = plt.figure(figsize=(10,10))
plt.plot(ntree, treerror,label='Test')
plt.plot(ngraph,trainerror,label='Train')
diferenceerror = np.array(treerror)-np.array(trainerror)
plt.plot(ngraph,diferenceerror,label='Diference')
plt.title('TREE REGRESOR ERROR CON 3 ATRIBUTOS')
plt.legend()
plt.xlabel('VARIACION DE PROFUNDIDAD')

plt.xticks([i for i in range(0,100,3)]) 

plt.show()

print("El minimo error para TREE REGRESSOR TEST lo encontramos en ", np.amin(treerror))
#print("El minimo error para TREE REGRESSOR Train lo encontramos en ", np.amin(trainerror))
# Out:
# El minimo error para TREE REGRESSOR TEST lo encontramos en  157289.7065919967

# %% [markdown]
# EN ESTE CASO SE PUEDE OBSERVAR QUE EL MEJOR HIPERPARAMETRO ESTA EN MAX_DEPTH = 9 APROXIMADAMENTE, AL IGUAL QUE ANTES
# YA QUE LUEGO EL ERROR SIGUE CRECIENDO Y LUEGO COMIENZA A HABER OVERFFITING.
# POR LO TANTO CON MAX_DEEPH=9 ----------> RMSE = 169186.51554492163

# %% [markdown]
# FINALMENTE COMPARANDO AMBOS MODELOS Y LOS ERRORES DE AMBOS, PROCEDO A ELEGIR EL MEJOR MODELO :
# EL MEJOR MODELO EN BASE A LO ANALIZADO ANTERIORMENTE ES EL MODELO DE
# TREE REGRESOR, CONSIDERANDO 3 ATRIBUTOS : BATHROOMS, SURFACE TOTAL Y ROOMS , CON UN MAX DEEPH = 9.
# COSNIDERO QUE ASI LOGRAMOS OBTENER UN MODELO BIEN AJUSTADO.

# %%
tree_regressor = DecisionTreeRegressor(max_depth=9, random_state=42)
tree_regressor.fit(X_train, y_train)
y_test_pred = tree_regressor.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
print(f'Raíz del error cuadrático medio en Test con TREE REGRESOR: {rmse_test}  Con max deeph de 9')
# Out:
# Raíz del error cuadrático medio en Test con TREE REGRESOR: 169186.51554492163  Con max deeph de 9

# %% [markdown]
# ¿Qué mejorarías?
#
# -PODRIA MEJORAR EL ANALISIS, OBSERVANDO CON MAYOR ATENCION LOS DATOS FALTANTES, QUIZAS ELIMINANDO ESTOS NO SEA LA MEJOR SOLUCION
# .PROBABLEMENTE REEMPLAZANDO DICHOS VALORES POR LA MEDIA, O LA MODA DE LA COLUMNA CORRESPONDIENTE PODRIA OBTENER MEJORES RESULTADOS.
# -TAMBIEN PODRIA MEJORARA AGREGANDO MAS ATRIBUTOS PARA ESTIMAR MI ETIQUETA PRECIO, CREO QUE MIENTRAS MAS ATRIBUTOS TENGA
# EL MODELO, MEJOR VA A REALIZAR PREDICCIONES.
# - ADEMAS TAMBIEN CONSIDERAR LA EVALUACION DEL MODELO EN BASE A LOS DEMAS ERRORES, QUIZAS PUEDA AYUDARME A TOMAR UNA MEJOR
# DECICION.
#
# ¿Qué información no estás usando que podría ayudar al modelo?
#
# - CONSIDERAR EL TIPO DE PROPIEDAD QUIZAS SEA ALGO FUNDAMENTAL PARA LA ESTIMACION DEL PRECIO, PERO AL REALIZAR UN MODELO DE
# REGRESION, NO SE PUDO TOMAR EN CONSIDERACION.
# - SI LA RESPUESTA A LA PREGUNTA PLANTEADA EN EL DESAFIO HUBIESE DADO UN BUEN RESULTADO, TAMBIEN CONSIDERO QUE ESA VARIABLE
# OBELISC DISTANCE, HUBIESE SIDO DE GRAN APORTE A MI PROBLEMA, PARA ESTIMAR LOS PRECIOS DE LOS MISMOS.
#
# ¿Qué información puede estar demás o repetida?
#
# LOS SIGUIENTES ATRIBUTOS:
#     -start_date
#     -end_date
#     -created_on
#     -currency
#     -title
#     -description
#     -operation_type
# FUE INFORMACION QUE ESTUVO DE MAS PARA LLEVAR A CABO MI ANALISIS, YA QUE AL NO ESTAR CORRELACIONADOS CON LAS ETIQUETAS PRECIO,
# NO SON DE INTERES PARA MI MODELO DE MACHINE LEARNING.
